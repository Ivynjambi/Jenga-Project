# %% [markdown]
# ### PROJECT 1

# %% [markdown]
# ### Analysis of the selected food prices in Nigeria from January 2017 to April 2020

# %% [markdown]
# We want to plot different food prices over time and compare different food items.

# %% [markdown]
# Packages needed to run this programme need to be imported

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# The dataset was sourced from openAFRICA, it contains prices of food items from January 2017 to April 2020, with an entry for each month, it also contains towns with the highest and lowest prices.
# Since we only need the columns with the item labels and food prices from Jan 2017 to April 2020, the other columns were deleted and the new csv saved as 'foods nigeria'.

# %% [markdown]
# First we will take a look at the data and view a few examples of the columns. View the top 5 columns and the bottom 5 columns to give us an idea of what the data contains.

# %%
food_prices = pd.read_csv("foods nigeria.csv")

# %%
food_prices.head(5).T
# Out:
#                              0                       1  \
# Item Labels  Bread sliced 500g  Gari white, sold loose
# 1-Jan-17                302.87                  219.56
# 1-Feb-17                299.75                  260.94
# 1-Mar-17                297.51                  273.67
# 1-Apr-17                296.63                  288.45
# 1-May-17                 307.7                  292.97
# 1-Jun-17                320.58                  315.61
# 1-Jul-17                314.47                   317.1
# 1-Aug-17                 304.2                  310.15
# 1-Sep-17                310.62                  301.99
# 1-Oct-17                305.88                   268.1
# 1-Nov-17                298.96                  251.91
# 1-Dec-17                290.05                  199.68
# 1-Jan-18                313.43                  229.26
# 1-Feb-18                314.17                  210.21
# 1-Mar-18                305.88                  209.12
# ...

# %%
food_prices.tail(5).T
# Out:
#                                  38            39                          40  \
# Item Labels  Rice local, sold loose  Sweet potato  Tilapia fish (epiya) fresh
# 1-Jan-17                     286.19        129.43                      792.18
# 1-Feb-17                     306.29        127.23                      795.27
# 1-Mar-17                     308.87        132.94                      798.07
# 1-Apr-17                      299.3        132.43                      800.77
# 1-May-17                     323.82        130.28                      805.21
# 1-Jun-17                     325.51        135.77                      817.62
# 1-Jul-17                     323.25        137.96                      823.34
# 1-Aug-17                     320.19        138.56                      820.29
# 1-Sep-17                      316.4           139                      795.64
# 1-Oct-17                      292.9        115.73                      822.39
# ...

# %% [markdown]
# We need to know the type of data each column includes, that is, either string, integer or float format.

# %%
food_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 41 columns):
# Item Labels    43 non-null object
# 1-Jan-17       43 non-null float64
# 1-Feb-17       43 non-null float64
# 1-Mar-17       43 non-null float64
# 1-Apr-17       43 non-null float64
# 1-May-17       43 non-null float64
# 1-Jun-17       43 non-null float64
# 1-Jul-17       43 non-null float64
# 1-Aug-17       43 non-null float64
# 1-Sep-17       43 non-null float64
# 1-Oct-17       43 non-null float64
# 1-Nov-17       43 non-null float64
# 1-Dec-17       43 non-null float64
# 1-Jan-18       43 non-null float64
# 1-Feb-18       43 non-null float64
# 1-Mar-18       43 non-null float64
# 1-Apr-18       43 non-null float64
# 1-May-18       43 non-null float64
# 1-Jun-18       43 non-null float64
# 1-Jul-18       43 non-null float64
# 1-Aug-18       43 non-null float64
# 1-Sep-18       43 non-null float64
# 1-Oct-18       43 non-null float64
# 1-Nov-18       43 non-null float64
# ...

# %% [markdown]
# To understand how the data is distributed we use describe, which gives us the mean, maximum, minimum values, e.t.c.

# %%
food_prices.describe()
# Out:
#           1-Jan-17     1-Feb-17     1-Mar-17     1-Apr-17     1-May-17  \
# count    43.000000    43.000000    43.000000    43.000000    43.000000
# mean    594.680233   604.477442   624.834651   626.724651   643.945116
# std     505.317539   512.329082   528.279412   545.717034   554.343122
# min      47.420000    42.900000    43.930000    46.220000    45.730000
# 25%     251.690000   245.945000   265.485000   281.705000   287.615000
# 50%     377.410000   392.040000   418.710000   388.460000   410.550000
# 75%     850.955000   855.240000   895.830000   861.835000   873.320000
# max    2204.120000  2150.180000  2189.550000  2319.910000  2388.050000
#
#           1-Jun-17     1-Jul-17     1-Aug-17     1-Sep-17     1-Oct-17  ...  \
# count    43.000000    43.000000    43.000000    43.000000    43.000000  ...
# mean    654.952093   652.791163   638.676512   631.800000   629.693256  ...
# std     560.241991   554.515998   527.290999   531.862507   533.524930  ...
# ...

# %% [markdown]
# First we visualize how the data looks like

# %% [markdown]
# We need to shorten the item labels, csv file modified, with 'F' standing for food, followed by the number n, the food's position in the original list is (n-1). For reference of the original item labels view below.

# %%
food_prices["Item Labels"]
# Out:
# 0                             Bread sliced 500g
# 1                        Gari white, sold loose
# 2                       Gari yellow, sold loose
# 3                          Rice, medium grained
# 4        Rice, imported high quality sold loose
# 5                                        Tomato
# 6     Wheat flour, prepacked (golden penny 2kg)
# 7                                     Yam tuber
# 8                       Agric eggs, medium size
# 9        Agric eggs, medium size (price of one)
# 10                     Beans, brown, sold loose
# 11           Beans, white black eye, sold loose
# 12                                Beef, bone in
# 13                               Beef, boneless
# 14                          Bread unsliced 500g
# 15                          Broken rice (Ofada)
# 16                               Catfish, dried
# 17                      Catfish (obokun), fresh
# 18                              Catfish, smoked
# 19                                 Chicken feet
# ...

# %% [markdown]
# As mentioned above, the item labels are shortened to F(n), the new csv file is saved as 'foods'.

# %%
prices = pd.read_csv("foods.csv")

# %% [markdown]
# Since for the item labels to be visible the plot size needs to be enlarged, therefore I've changed the default size to be width = 17 and height = 5.

# %% [markdown]
# Below is a scatter plot of the prices of different foods during the first recorded month, that is January 2017 and the last recorded month, that is April 2020.

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.scatter(prices["1-Apr-20"], prices["1-Jan-17"])
plt.xlabel("Food Prices on 1st April, 2020")
plt.ylabel("Food Prices on 1st January 2017")
plt.title("Scatter plot of the food prices in 1st January 2017 and 1st April 2020")
plt.show()

# %% [markdown]
# From the above scatter plot of the last month recorded and the first month recorded;
# We can see that most food items are priced below 500 Naira.
# We can also see a few outliers in the data, passed the items priced above 1500 Naira.
# Overall, there is a strong, positive, linear association between the prices in the first month and the prices in the last month.

# %% [markdown]
# We can also print out the food items whose prices are above 1500 Naira between Jan 2017 and Apr 2020

# %%
prices[(prices["1-Jan-17"]>1500)& (prices["1-Apr-20"]>1500)]
# Out:
#    Item Labels  1-Jan-17  1-Feb-17  1-Mar-17  1-Apr-17  1-May-17  1-Jun-17  \
# 16         F17   2204.12   2150.18   2189.55   2189.10   2213.66   2255.24
# 31         F32   1812.03   1955.10   2084.81   2319.91   2388.05   2416.28
#
#     1-Jul-17  1-Aug-17  1-Sep-17  ...  1-Jul-19  1-Aug-19  1-Sep-19  1-Oct-19  \
# 16   2215.25   2176.82   2159.00  ...   1700.51   1712.11    1709.8   1697.55
# 31   2395.79   2161.70   2204.04  ...   1763.72   1768.23    1762.5   1741.27
#
#     1-Nov-19  1-Dec-19  1-Jan-20  1-Feb-20  1-Mar-20  1-Apr-20
# 16   1723.23   1732.45   1720.55   1713.30   1711.32   1724.52
# 31   1756.42   1774.96   1758.76   1764.13   1742.72   1762.88
#
# [2 rows x 41 columns]

# %% [markdown]
# We find that the food items that are constantly above 1500 Naira from 2017 to 2020 are F17 and F32, that is 'Catfish, dried' and 'Mudfish, dried' respectively.

# %%
#prices.plot()
#plt.xlabel("Item Labels")
#plt.ylabel("Food Prices")
#plt.show()

# %% [markdown]
# Since the code above shows the relationship between the food items and their prices through out 2017-2020, which is too compact and hard to read, we will get and average of the prices through out 2017 to 2020, then plot the food items against the average prices.

# %%
av_row = prices.mean(axis=1)
print(av_row)
# Out:
# 0      303.34375
# 1      207.64575
# 2      237.04450
# 3      331.96700
# 4      388.16025
# 5      281.47950
# 6      655.57375
# 7      234.33900
# 8      485.03800
# 9       42.00575
# 10     360.41425
# 11     323.36150
# 12    1034.55950
# 13    1282.32600
# 14     276.01025
# 15     398.71850
# 16    1904.13700
# 17    1000.82300
# 18    1325.28125
# 19     777.33375
# 20     938.30450
# 21    1270.71475
# 22     160.04150
# 23     188.46775
# 24    1675.48800
# 25     559.23625
# 26    1210.54925
# 27     292.11625
# 28     893.19525
# 29     167.98925
# 30     170.83200
# 31    1937.66675
# 32    1036.28750
# 33     234.71925
# 34     472.26625
# 35     239.61050
# 36     223.20825
# 37     337.09050
# 38     296.32200
# 39     139.08450
# 40     870.19800
# 41     962.81550
# 42     525.34175
# dtype: float64

# %% [markdown]
# Below is a bar plot of the average food prices from 2017-2020, against the food item labels

# %%
plt.rcParams["figure.figsize"] = [17, 5]
plt.bar(prices['Item Labels'], av_row)
plt.xlabel("Item labels")
plt.ylabel("Average of food prices from 2017-2020")
plt.title("Bar plot of the average food prices of different foods in Nigeria.")
plt.show()

# %% [markdown]
# From above, we can see that item F10-'Agric eggs, medium size (price of one)' has the lowest average price, which makes sense since it is a record of the price of each Agric egg. Right after we have item F40-'Sweet potato' which has the next lowest average price recorded between 2017-2020.
# The highest average priced item is item F32-'Mudfish, dried' followed right after by item F17-'Catfish, dried'.

# %% [markdown]
# Below is a histogram of the average of the food item prices through 2017-2020, so as to summarize the distribution of the data set.

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.ylabel("Frequency")
plt.xlabel("Average prices")
plt.title("Average prices of food items distribution in 2017-2020")
hist = av_row.hist()

# %% [markdown]
# From the figure above we can tell how the data (Average prices of the food items from 2017-2020) is distributed.
# The figure represents a right-skewed distribution, which means the mean has the largest value of the measures of central tendancy, which is located to the right of the distribution, and the mode is the smallest value, which is located to the left of the distribution.

# %% [markdown]
# Since the data on the prices is per month, it's combined on excel to have the prices recorded yearly, and the new csv file is 'foods-yr'.

# %%
df = pd.read_csv("foods-yr.csv")

# %% [markdown]
# We take a look at the data by viewing the first 5 columns, with the column 'years' as the DataFrame's index

# %%
df = df.set_index("Years")
df.head(5)
# Out:
#            F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# Years
# 2017   304.10  275.01  304.73  333.91  394.89  312.93  634.27  254.00  499.87
# 2018   306.05  201.96  244.34  318.81  370.34  299.51  656.52  260.56  497.52
# 2019   298.77  159.03  176.68  327.38  377.99  241.55  668.83  198.33  466.04
# 2020   306.67  168.45  193.20  379.38  451.95  252.83  676.89  204.70  460.08
#
#          F10  ...     F34     F35     F36     F37     F38     F39     F40  \
# Years         ...
# 2017   44.05  ...  234.71  465.99  242.27  224.96  339.85  305.05  129.24
# 2018   41.47  ...  247.89  494.10  262.47  238.53  325.69  279.54  145.63
# 2019   41.09  ...  223.02  461.60  221.35  209.94  331.17  292.47  139.92
# 2020   40.23  ...  230.35  457.59  217.85  211.79  380.78  332.07  146.48
#
#           F41     F42     F43
# Years
# 2017   836.95  998.38  531.89
# 2018   916.64  936.69  540.97
# 2019   858.84  952.79  501.68
# 2020   864.68  964.61  529.80
#
# ...

# %% [markdown]
# Below is a line graph of three different food items that are named in the key, showing their prices from 2017 to 2020, allowing us to see if there are any visible patterns.

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.plot(df["F1"], label= "Bread, sliced 500g")
plt.plot(df["F3"], label= "Gari yellow, sold loose")
plt.plot(df["F16"], label= "Broken rice (Ofada)")

plt.xlabel("Years")
plt.ylabel("Food Prices")
plt.title("Prices of different food items from 2017-2020")
plt.legend()
plt.show()

# %% [markdown]
# Above we see the visualization of the price of sliced bread, gari(yellow) and broken rice from 2017-2020.
# Initially for the price of bread the price rises till 2018, then a drastic drop all through the year to 2019, while for the other two items, the prices drops from 2017 to 2019. Then the price begins to rapidly increase for all three items all through to April, 2020, where the price of sliced bread, gari yellow and broken rice is at it's highest, that is, 316.55 Naira, 211.83 Naira and 390.54 Naira respectively.

# %% [markdown]
# What could have caused this rapid increase in food prices from 2019?
# There are a number of factors to consider and one of them is the ban on dollar access. The Nigerian president ordered the central bank to stop providing foreign exchange for food and fertilizer imports, in an effort to boost local farming production. In turn the prices of food has increased and is likely to continue increasing with the pandemic faced through 2020-2021.
